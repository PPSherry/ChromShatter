# %%
import torch
import torchvision.models as models
from torchvision import transforms
from PIL import Image
import os
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.metrics import roc_curve, auc, accuracy_score, classification_report
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
import joblib

# %% [markdown]
# # 1. 初始化模型和预处理步骤

# %%
# 设置设备
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
print(f"使用设备: {device}")

# 初始化ResNet18
weights = models.ResNet18_Weights.IMAGENET1K_V1
model = models.resnet18(weights=weights).to(device)
model = torch.nn.Sequential(*list(model.children())[:-1])  # 移除分类层
model.eval()

# 图像预处理
preprocess = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])
# Out:
# 使用设备: mps

# %% [markdown]
# # 2. 特征提取函数

# %%
def extract_features_batch(image_paths, batch_size=32):
    """从图像中批量提取特征"""
    features_list = []
    for i in range(0, len(image_paths), batch_size):
        batch_paths = image_paths[i:i + batch_size]
        batch_images = []
        for p in batch_paths:
            try:
                img = Image.open(p).convert("RGB")
                batch_images.append(preprocess(img))
            except Exception as e:
                print(f"处理图像 {p} 时出错: {e}")
                # 添加一个零张量作为替代
                batch_images.append(torch.zeros(3, 224, 224))
        
        batch_tensor = torch.stack(batch_images).to(device)
        with torch.no_grad():
            batch_features = model(batch_tensor)
            batch_features = batch_features.squeeze(-1).squeeze(-1)
        features_list.append(batch_features.cpu().numpy())
        print(f"已处理 {i+len(batch_paths)}/{len(image_paths)} 张图像")
    
    return np.vstack(features_list)

# %% [markdown]
# # 3. 数据加载和准备

# %%
def load_data(data_path, image_dir):
    """加载和准备数据"""
    df = pd.read_csv(data_path, sep='\t')
    
    # 展示数据集分布
    print(f"数据集大小: {len(df)}")
    print(f"标签分布:\n{df['label'].value_counts()}")
    
    # 确保CNV特征是数值型
    for col in ['cn_2', 'cn_3', 'cn_segments']:
        df[col] = pd.to_numeric(df[col], errors='coerce')
        # 填充缺失值
        df[col].fillna(df[col].median(), inplace=True)
    
    # 构建完整图像路径
    image_paths = [os.path.join(image_dir, img) for img in df['image_path']]
    
    # 检查图像是否存在
    valid_paths = []
    valid_indices = []
    for i, path in enumerate(image_paths):
        if os.path.exists(path):
            valid_paths.append(path)
            valid_indices.append(i)
        else:
            print(f"警告: 图像 {path} 不存在")
    
    # 筛选有效数据
    df_valid = df.iloc[valid_indices].reset_index(drop=True)
    features = df_valid[['cn_2', 'cn_3', 'cn_segments']].values
    labels = df_valid['label'].values
    
    return df_valid, valid_paths, features, labels

# 加载训练数据
print("加载训练数据...")
train_df, train_image_paths, train_cnv_features, train_labels = load_data(
    '/Volumes/T7-shield/CS-Bachelor-Thesis/CNN_model/model_data/train_data.tsv',
    '/Volumes/T7-shield/CS-Bachelor-Thesis/CNN_model/model_data/train'
)

# 加载测试数据
print("加载测试数据...")
test_df, test_image_paths, test_cnv_features, test_labels = load_data(
    '/Volumes/T7-shield/CS-Bachelor-Thesis/CNN_model/model_data/test_data.tsv',
    '/Volumes/T7-shield/CS-Bachelor-Thesis/CNN_model/model_data/test'
)
# Out:
# 加载训练数据...
# 数据集大小: 2564
# 标签分布:
# label
# 1    1775
# 0     789
# Name: count, dtype: int64
# 加载测试数据...
# 数据集大小: 284
# 标签分布:
# label
# 1    212
# 0     72
# Name: count, dtype: int64

# %% [markdown]
# # 4. 特征提取

# %%
# 提取训练图像特征
print("提取训练图像特征...")
train_image_features = extract_features_batch(train_image_paths)
print(f"训练图像特征形状: {train_image_features.shape}")

# 提取测试图像特征
print("提取测试图像特征...")
test_image_features = extract_features_batch(test_image_paths)
print(f"测试图像特征形状: {test_image_features.shape}")
# Out:
# 提取训练图像特征...
# 已处理 32/2564 张图像
# 已处理 64/2564 张图像
# 已处理 96/2564 张图像
# 已处理 128/2564 张图像
# 已处理 160/2564 张图像
# 已处理 192/2564 张图像
# 已处理 224/2564 张图像
# 已处理 256/2564 张图像
# 已处理 288/2564 张图像
# 已处理 320/2564 张图像
# 已处理 352/2564 张图像
# 已处理 384/2564 张图像
# 已处理 416/2564 张图像
# 已处理 448/2564 张图像
# 已处理 480/2564 张图像
# 已处理 512/2564 张图像
# 已处理 544/2564 张图像
# 已处理 576/2564 张图像
# 已处理 608/2564 张图像
# 已处理 640/2564 张图像
# 已处理 672/2564 张图像
# 已处理 704/2564 张图像
# 已处理 736/2564 张图像
# 已处理 768/2564 张图像
# 已处理 800/2564 张图像
# 已处理 832/2564 张图像
# 已处理 864/2564 张图像
# 已处理 896/2564 张图像
# 已处理 928/2564 张图像
# 已处理 960/2564 张图像
# 已处理 992/2564 张图像
# 已处理 1024/2564 张图像
# 已处理 1056/2564 张图像
# 已处理 1088/2564 张图像
# 已处理 1120/2564 张图像
# 已处理 1152/2564 张图像
# 已处理 1184/2564 张图像
# 已处理 1216/2564 张图像
# 已处理 1248/2564 张图像
# 已处理 1280/2564 张图像
# 已处理 1312/2564 张图像
# 已处理 1344/2564 张图像
# 已处理 1376/2564 张图像
# 已处理 1408/2564 张图像
# 已处理 1440/2564 张图像
# 已处理 1472/2564 张图像
# 已处理 1504/2564 张图像
# 已处理 1536/2564 张图像
# 已处理 1568/2564 张图像
# 已处理 1600/2564 张图像
# 已处理 1632/2564 张图像
# 已处理 1664/2564 张图像
# 已处理 1696/2564 张图像
# 已处理 1728/2564 张图像
# 已处理 1760/2564 张图像
# 已处理 1792/2564 张图像
# 已处理 1824/2564 张图像
# 已处理 1856/2564 张图像
# 已处理 1888/2564 张图像
# 已处理 1920/2564 张图像
# 已处理 1952/2564 张图像
# 已处理 1984/2564 张图像
# 已处理 2016/2564 张图像
# 已处理 2048/2564 张图像
# 已处理 2080/2564 张图像
# 已处理 2112/2564 张图像
# 已处理 2144/2564 张图像
# 已处理 2176/2564 张图像
# 已处理 2208/2564 张图像
# 已处理 2240/2564 张图像
# 已处理 2272/2564 张图像
# 已处理 2304/2564 张图像
# 已处理 2336/2564 张图像
# 已处理 2368/2564 张图像
# 已处理 2400/2564 张图像
# 已处理 2432/2564 张图像
# 已处理 2464/2564 张图像
# 已处理 2496/2564 张图像
# 已处理 2528/2564 张图像
# 已处理 2560/2564 张图像
# 已处理 2564/2564 张图像
# 训练图像特征形状: (2564, 512)
# 提取测试图像特征...
# 已处理 32/284 张图像
# 已处理 64/284 张图像
# 已处理 96/284 张图像
# 已处理 128/284 张图像
# 已处理 160/284 张图像
# 已处理 192/284 张图像
# 已处理 224/284 张图像
# 已处理 256/284 张图像
# 已处理 284/284 张图像
# 测试图像特征形状: (284, 512)

# %% [markdown]
# # 5. 特征处理和可视化

# %%
# 可视化CNV特征分布
def visualize_features(df, feature_names):
    """可视化特征分布"""
    plt.figure(figsize=(12, 4))
    for i, name in enumerate(feature_names):
        plt.subplot(1, 3, i+1)
        plt.hist(df[name], bins=30)
        plt.title(f'{name} 分布')
        plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

# 显示原始特征分布
features_names = ['cn_2', 'cn_3', 'cn_segments']
visualize_features(train_df, features_names)

# 标准化CNV特征
scaler = StandardScaler() # Z-score normalization
train_cnv_features_scaled = scaler.fit_transform(train_cnv_features)
test_cnv_features_scaled = scaler.transform(test_cnv_features)

# 可视化标准化后的特征
plt.figure(figsize=(12, 4))
for i, name in enumerate(features_names):
    plt.subplot(1, 3, i+1)
    plt.hist(train_cnv_features_scaled[:, i], bins=30)
    plt.title(f'标准化后的 {name} 分布')
    plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# 合并特征
train_combined_features = np.hstack((train_image_features, train_cnv_features_scaled))
test_combined_features = np.hstack((test_image_features, test_cnv_features_scaled))

print(f"训练集合并特征形状: {train_combined_features.shape}")
print(f"测试集合并特征形状: {test_combined_features.shape}")
# Out:
# /var/folders/02/g47thkvs7c3d1nbgkbzhs6j80000gn/T/ipykernel_65444/2487153198.py:10: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from current font.
#   plt.tight_layout()
# /var/folders/02/g47thkvs7c3d1nbgkbzhs6j80000gn/T/ipykernel_65444/2487153198.py:10: UserWarning: Glyph 24067 (\N{CJK UNIFIED IDEOGRAPH-5E03}) missing from current font.
#   plt.tight_layout()
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 24067 (\N{CJK UNIFIED IDEOGRAPH-5E03}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /var/folders/02/g47thkvs7c3d1nbgkbzhs6j80000gn/T/ipykernel_65444/2487153198.py:29: UserWarning: Glyph 26631 (\N{CJK UNIFIED IDEOGRAPH-6807}) missing from current font.
#   plt.tight_layout()
# /var/folders/02/g47thkvs7c3d1nbgkbzhs6j80000gn/T/ipykernel_65444/2487153198.py:29: UserWarning: Glyph 20934 (\N{CJK UNIFIED IDEOGRAPH-51C6}) missing from current font.
#   plt.tight_layout()
# /var/folders/02/g47thkvs7c3d1nbgkbzhs6j80000gn/T/ipykernel_65444/2487153198.py:29: UserWarning: Glyph 21270 (\N{CJK UNIFIED IDEOGRAPH-5316}) missing from current font.
#   plt.tight_layout()
# /var/folders/02/g47thkvs7c3d1nbgkbzhs6j80000gn/T/ipykernel_65444/2487153198.py:29: UserWarning: Glyph 21518 (\N{CJK UNIFIED IDEOGRAPH-540E}) missing from current font.
#   plt.tight_layout()
# /var/folders/02/g47thkvs7c3d1nbgkbzhs6j80000gn/T/ipykernel_65444/2487153198.py:29: UserWarning: Glyph 30340 (\N{CJK UNIFIED IDEOGRAPH-7684}) missing from current font.
#   plt.tight_layout()
# /var/folders/02/g47thkvs7c3d1nbgkbzhs6j80000gn/T/ipykernel_65444/2487153198.py:29: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from current font.
#   plt.tight_layout()
# /var/folders/02/g47thkvs7c3d1nbgkbzhs6j80000gn/T/ipykernel_65444/2487153198.py:29: UserWarning: Glyph 24067 (\N{CJK UNIFIED IDEOGRAPH-5E03}) missing from current font.
#   plt.tight_layout()
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 26631 (\N{CJK UNIFIED IDEOGRAPH-6807}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 20934 (\N{CJK UNIFIED IDEOGRAPH-51C6}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 21270 (\N{CJK UNIFIED IDEOGRAPH-5316}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 21518 (\N{CJK UNIFIED IDEOGRAPH-540E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 30340 (\N{CJK UNIFIED IDEOGRAPH-7684}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 24067 (\N{CJK UNIFIED IDEOGRAPH-5E03}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# 训练集合并特征形状: (2564, 515)
# 测试集合并特征形状: (284, 515)

# %% [markdown]
# # 6. 保存处理后的特征

# %%
# 创建目录
os.makedirs('/Volumes/T7-shield/CS-Bachelor-Thesis/CNN_model/model_data/processed_data', exist_ok=True)

# 保存特征和标签
np.save('/Volumes/T7-shield/CS-Bachelor-Thesis/CNN_model/model_data/processed_data/train_combined_features.npy', train_combined_features)
np.save('/Volumes/T7-shield/CS-Bachelor-Thesis/CNN_model/model_data/processed_data/train_labels.npy', train_labels)
np.save('/Volumes/T7-shield/CS-Bachelor-Thesis/CNN_model/model_data/processed_data/test_combined_features.npy', test_combined_features)
np.save('/Volumes/T7-shield/CS-Bachelor-Thesis/CNN_model/model_data/processed_data/test_labels.npy', test_labels)

# 保存数据处理器
joblib.dump(scaler, '/Volumes/T7-shield/CS-Bachelor-Thesis/CNN_model/model_data/processed_data/cnv_scaler.pkl')

# 保存特征维度信息
np.save('/Volumes/T7-shield/CS-Bachelor-Thesis/CNN_model/model_data/processed_data/feature_dimensions.npy', 
       np.array([train_image_features.shape[1], train_cnv_features_scaled.shape[1]]))

print("所有数据处理完成并保存")
# Out:
# 所有数据处理完成并保存

# %% [markdown]
# # 7. 10折交叉验证训练
# 最佳参数: {'C': 1, 'class_weight': 'balanced', 'penalty': 'l2', 'solver': 'saga'}
# 交叉验证AUC: 0.9779

# %%
def train_with_cross_validation(X, y, n_splits=10, random_state=42):
    """使用交叉验证训练模型"""
    cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=random_state)
    
    # 定义超参数网格
    param_grid = {
        'C': [0.001, 0.01, 0.1, 1, 10, 100],
        'penalty': ['l1', 'l2', 'elasticnet', None],
        'solver': ['liblinear', 'saga'],
        'class_weight': [None, 'balanced']
    }
    
    # 创建网格搜索
    grid_search = GridSearchCV(
        LogisticRegression(max_iter=10000), 
        param_grid, 
        cv=cv, 
        scoring='roc_auc',
        n_jobs=-1
    )
    
    # 训练模型
    print("开始网格搜索...")
    grid_search.fit(X, y)
    
    # 获取最佳模型
    best_model = grid_search.best_estimator_
    print(f"最佳参数: {grid_search.best_params_}")
    print(f"交叉验证AUC: {grid_search.best_score_:.4f}")
    
    return best_model, grid_search, cv

# 执行交叉验证训练
best_model, grid_search, cv = train_with_cross_validation(train_combined_features, train_labels)
# Out:
# 开始网格搜索...
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 360 fits failed out of a total of 960.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 120 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 1193, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 71, in _check_solver
#     raise ValueError(
# ValueError: Only 'saga' solver supports elasticnet penalty, got solver=liblinear.
#
# --------------------------------------------------------------------------------
# 120 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 1203, in fit
#     raise ValueError("l1_ratio must be specified when penalty is elasticnet.")
# ValueError: l1_ratio must be specified when penalty is elasticnet.
#
# --------------------------------------------------------------------------------
# 120 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 1193, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 76, in _check_solver
#     raise ValueError("penalty=None is not supported for the liblinear solver")
# ValueError: penalty=None is not supported for the liblinear solver
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/xurui/miniforge3/envs/d2l/lib/python3.9/site-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the test scores are non-finite: [0.78032809 0.78032809 0.89544285 0.89944798        nan        nan
#         nan 0.97345086 0.78032809 0.78032809 0.89737429 0.90336709
#         nan        nan        nan 0.97341554 0.86690753 0.86335378
#  0.94938724 0.95153593        nan        nan        nan 0.9734438
#  0.86306956 0.86481906 0.9517645  0.9547063         nan        nan
#         nan 0.97340843 0.95131096 0.95554219 0.97466805 0.97565542
#         nan        nan        nan 0.97344383 0.95445755 0.95768742
#  0.97531092 0.97623372        nan        nan        nan 0.9733727
#  0.97485104 0.97616543 0.97778662 0.97787983        nan        nan
#         nan 0.97343655 0.97518696 0.97644477 0.97765849 0.97788725
#         nan        nan        nan 0.97337977 0.97208634 0.97480048
#  0.97335621 0.97471551        nan        nan        nan 0.97345096
#  0.97196085 0.97466508 0.97327755 0.97475856        nan        nan
#         nan 0.97340137 0.96550132 0.9735583  0.9704699  0.97361517
#         nan        nan        nan 0.97342238 0.96796581 0.97347249
#  0.97019804 0.9735869         nan        nan        nan 0.9733942 ]
#   warnings.warn(
# 最佳参数: {'C': 1, 'class_weight': 'balanced', 'penalty': 'l2', 'solver': 'saga'}
# 交叉验证AUC: 0.9779

# %% [markdown]
# # 8. ROC曲线绘制

# %%
def plot_cv_roc_curves(X, y, cv, best_params, output_path=None):
    """绘制交叉验证ROC曲线"""
    plt.figure(figsize=(10, 8))
    tprs = []
    aucs = []
    mean_fpr = np.linspace(0, 1, 100)
    
    for i, (train_idx, test_idx) in enumerate(cv.split(X, y)):
        X_fold_train, X_fold_test = X[train_idx], X[test_idx]
        y_fold_train, y_fold_test = y[train_idx], y[test_idx]
        
        model = LogisticRegression(**best_params, max_iter=10000)
        model.fit(X_fold_train, y_fold_train)
        
        y_fold_prob = model.predict_proba(X_fold_test)[:, 1]
        fpr, tpr, _ = roc_curve(y_fold_test, y_fold_prob)
        
        interp_tpr = np.interp(mean_fpr, fpr, tpr)
        interp_tpr[0] = 0.0
        tprs.append(interp_tpr)
        
        fold_auc = auc(fpr, tpr)
        aucs.append(fold_auc)
        plt.plot(fpr, tpr, alpha=0.3, label=f'Fold {i+1} AUC: {fold_auc:.3f}')
    
    # 平均ROC曲线
    mean_tpr = np.mean(tprs, axis=0)
    mean_tpr[-1] = 1.0
    mean_auc = auc(mean_fpr, mean_tpr)
    std_auc = np.std(aucs)
    plt.plot(mean_fpr, mean_tpr, color='b', 
             label=f'Mean ROC (AUC = {mean_auc:.3f} ± {std_auc:.3f})',
             lw=2, alpha=0.8)
    
    plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r', alpha=.8)
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('10-Fold Cross-Validation ROC Curves')
    plt.legend(loc="lower right")
    
    if output_path:
        plt.savefig(output_path)
    
    plt.show()
    
    return mean_auc, std_auc

# 绘制交叉验证ROC曲线
cv_output_path = '/Volumes/T7-shield/CS-Bachelor-Thesis/CNN_model/model_data/cv_roc_curve.png'
mean_auc, std_auc = plot_cv_roc_curves(
    train_combined_features, 
    train_labels, 
    cv, 
    grid_search.best_params_,
    cv_output_path
)

# %% [markdown]
# # 9. 特征重要性分析

# %%
def analyze_feature_importance(model, X_train, output_path=None):
    """分析特征重要性"""
    if hasattr(model, 'coef_'):
        # 加载特征维度
        dimensions = np.load('/Volumes/T7-shield/CS-Bachelor-Thesis/CNN_model/model_data/processed_data/feature_dimensions.npy')
        img_features_dim = dimensions[0]
        cnv_features_dim = dimensions[1]
        
        # 创建特征名称
        feature_names = [f'img_{i}' for i in range(img_features_dim)]
        feature_names.extend(['cn_2', 'cn_3', 'cn_segments'])
        
        # 获取系数
        coefs = model.coef_[0]
        
        # 计算特征重要性
        importance = np.abs(coefs)
        
        # 找出最重要的特征（前20个）
        top_indices = np.argsort(importance)[-20:]
        
        plt.figure(figsize=(10, 12))
        plt.barh([feature_names[i] for i in top_indices], importance[top_indices])
        plt.xlabel('特征重要性 (系数绝对值)')
        plt.title('Top 20 重要特征')
        plt.tight_layout()
        
        if output_path:
            plt.savefig(output_path)
        
        plt.show()
        
        # 单独查看CNV特征的重要性
        cnv_indices = np.arange(img_features_dim, img_features_dim + cnv_features_dim)
        cnv_names = ['cn_2', 'cn_3', 'cn_segments']
        
        plt.figure(figsize=(8, 5))
        plt.barh(cnv_names, np.abs(coefs[cnv_indices]))
        plt.xlabel('特征重要性 (系数绝对值)')
        plt.title('CNV特征重要性')
        plt.tight_layout()
        
        if output_path:
            plt.savefig(output_path.replace('.png', '_cnv.png'))
        
        plt.show()

# 分析特征重要性
importance_output_path = '/Volumes/T7-shield/CS-Bachelor-Thesis/CNN_model/model_data/feature_importance.png'
analyze_feature_importance(best_model, train_combined_features, importance_output_path)

# %% [markdown]
# # 10.  保存最佳模型

# %%
# 保存模型
model_path = '/Volumes/T7-shield/CS-Bachelor-Thesis/CNN_model/model_data/best_model.pkl'
joblib.dump(best_model, model_path)
print(f"最佳模型已保存到 {model_path}")

# %% [markdown]
# # 11. 独立测试集评估

# %%
def evaluate_on_test_set(model, X_test, y_test, output_path=None):
    """在独立测试集上评估模型"""
    # 预测
    test_pred = model.predict(X_test)
    test_prob = model.predict_proba(X_test)[:, 1]
    
    # 准确率
    test_accuracy = accuracy_score(y_test, test_pred)
    print(f"测试集准确率: {test_accuracy:.4f}")
    
    # 分类报告
    print("分类报告:")
    print(classification_report(y_test, test_pred))
    
    # ROC曲线和AUC
    fpr, tpr, _ = roc_curve(y_test, test_prob)
    test_auc = auc(fpr, tpr)
    
    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, lw=2, label=f'ROC 曲线 (AUC = {test_auc:.3f})')
    plt.plot([0, 1], [0, 1], 'k--', lw=2)
    plt.xlabel('假阳性率')
    plt.ylabel('真阳性率')
    plt.title('测试集 ROC 曲线')
    plt.legend(loc="lower right")
    
    if output_path:
        plt.savefig(output_path)
    
    plt.show()
    
    return test_accuracy, test_auc

# 评估测试集
test_output_path = '/Volumes/T7-shield/CS-Bachelor-Thesis/CNN_model/model_data/test_roc_curve.png'
test_accuracy, test_auc = evaluate_on_test_set(best_model, test_combined_features, test_labels, test_output_path)

print("模型训练和评估完成!")
